# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/DL Project/tf2-neural-style-transfer"
os.chdir(path)
os.listdir(path)
# Out:
# ['README.MD',
#  'utils.py',
#  'requirements.txt',
#  'train.py',
#  'model.py',
#  'output',
#  'samples',
#  '__pycache__',
#  'images',
#  '.ipynb_checkpoints',
#  'settings.py',
#  'Untitled0.ipynb']

# %%
# !python train.py
# Out:
# 2021-12-21 10:23:34.428448: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# ...
# 80150528/80134624 [==============================] - 1s 0us/step
# Epoch 1/20: 100% 100/100 [00:31<00:00,  3.20it/s, loss=35485.3047]
# Epoch 2/20: 100% 100/100 [00:26<00:00,  3.81it/s, loss=16166.1943]
# Epoch 3/20: 100% 100/100 [00:26<00:00,  3.81it/s, loss=10881.1182]
# Epoch 4/20: 100% 100/100 [00:26<00:00,  3.79it/s, loss=8400.2207]
# Epoch 5/20: 100% 100/100 [00:26<00:00,  3.78it/s, loss=6921.8848]
# Epoch 6/20: 100% 100/100 [00:26<00:00,  3.80it/s, loss=5956.2070]
# Epoch 7/20: 100% 100/100 [00:26<00:00,  3.74it/s, loss=5290.1587]
# Epoch 8/20: 100% 100/100 [00:26<00:00,  3.78it/s, loss=4812.5322]
# Epoch 9/20: 100% 100/100 [00:26<00:00,  3.79it/s, loss=4459.5962]
# Epoch 10/20: 100% 100/100 [00:26<00:00,  3.79it/s, loss=4191.1606]
# ...
